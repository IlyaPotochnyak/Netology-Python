# %% [markdown]
# Домашнее задание к лекции "Функции"
# Вам нужно помочь секретарю автоматизировать работу. Для этого нужно написать программу, которая будет на основе хранимых данных исполнять пользовательские команды.
#
# Исходные данные имеют следующую структуру:
#
# перечень всех документов
# documents = [
#  {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
#  {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
#  {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
# ]
# перечень полок, на которых хранятся документы (если документ есть в documents, то он обязательно должен быть и в directories)
# directories = {
#  '1': ['2207 876234', '11-2'],
#  '2': ['10006'],
#  '3': []
# }
# Общие требования к программе:
#
# код должен быть грамотно декомпозирован (каждая функция отвечает за свою конкретную задачу, дублирующийся функционал переиспользуется, а его код не повторяется);
# в коде отсутствуют глобальные переменные (за исключением documents и directories);
# пользовательский ввод обрабатывается в цикле while до тех пор, пока пользователь явно не завершит программу (вводом команды "q").

# %% [markdown]
# Задание 1
# Пункт 1. Пользователь по команде "p" может узнать владельца документа по его номеру
# Примеры работы:
#
# 1.
#
# Введите команду:
# p
#
# Введите номер документа:
# 10006
# Результат:
# Владелец документа: Аристарх Павлов
#
# 2.
#
# Введите команду:
# p
#
# Введите номер документа:
# 12345
# Результат:
# Документ не найден в базе

# %%
documents = [
 {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
 {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
 {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
# перечень полок, на которых хранятся документы (если документ есть в documents, то он обязательно должен быть и в directories)
directories = {
 '1': ['2207 876234', '11-2'],
 '2': ['10006'],
 '3': []
}

# %%
def get_doc_owner_by_number(doc_list, number):
    for document in doc_list:
        if number == document['number']:            
            return(f"Владелец документа: {document['name']}")
    return("Документ не найден в базе")            
        
# get_doc_owner_by_number(documents, '11-')

# %% [markdown]
# Пункт 2. Пользователь по команде "s" может по номеру документа узнать на какой полке он хранится
# Примеры работы:
#
# 1.
#
# Введите команду:
# s
#
# Введите номер документа:
# 10006
# Результат:
# Документ хранится на полке: 2
#
# 2.
#
# Введите команду:
# p
#
# Введите номер документа:
# 12345
# Результат:
# Документ не найден в базе

# %%
def get_doc_directory_by_number(dir_list, number):
    for directory in dir_list:
        for item in dir_list[directory]:
            if number in item:
                return(f"Документ хранится на полке: {directory}")
#             print(item)
    return('Документ не найден в базе')

# get_doc_directory_by_number(directories, input())

# %% [markdown]
# Пункт 3. Пользователь по команде "l" может увидеть полную информацию по всем документам
# Пример работы:
#
# Введите команду:
# l
# Результат:
#
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2

# %%
def get_doc_list(doc_list, dir_list):
    for doc in doc_list:
        doc_dir = get_doc_directory_by_number(directories, doc['number']).split()
        
        print(f"№: {doc['number']}, тип: {doc['type']}, владелец: {doc['name']}, полка хранения: {doc_dir[-1]}")
        
# get_doc_list(documents, directories)

# %% [markdown]
# Пункт 4. Пользователь по команде "ads" может добавить новую полку
# Примеры работы:
#
# 1.
#
# Введите команду:
# ads
#
# Введите номер полки:
# 10
# Результат:
# Полка добавлена. Текущий перечень полок: 1, 2, 3, 10.
#
# 2.
#
# Введите команду:
# ads
#
# Введите номер полки:
# 1
# Результат:
# Такая полка уже существует. Текущий перечень полок: 1, 2, 3.

# %%
def add_new_directory(dir_list, number):
#     dir_numbers = [i for i in dir_list]
    if number not in dir_list:
#         print('not in list')
        dir_list[number] = []
        return(f"Полка добавлена. Текущий перечень полок: {', '.join(dir_list)}")
    return(f"Такая полка уже существует. Текущий перечень полок: {', '.join(dir_list)}")

# add_new_directory(directories, '98')

# %% [markdown]
# Пункт 5. Пользователь по команде "ds" может удалить существующую полку из данных (только если она пустая)
# Примеры работы:
#
# 1.
#
# Введите команду:
# ds
#
# Введите номер полки:
# 3
# Результат:
# Полка удалена. Текущий перечень полок: 1, 2.
#
# 2.
#
# Введите команду:
# ds
#
# Введите номер полки:
# 1
# Результат:
# На полке есть документа, удалите их перед удалением полки. Текущий перечень полок: 1, 2, 3.
#
# 3.
#
# Введите команду:
# ds
#
# Введите номер полки:
# 4
# Результат:
# Такой полки не существует. Текущий перечень полок: 1, 2, 3.

# %%
def delete_directory_by_number(dir_list, number):
    if number in dir_list:
        if len(dir_list[number]) > 0:
            return(f"На полке есть документы, удалите их перед удалением полки. Текущий перечень полок: {', '.join(dir_list)}")
        dir_list.pop(number)
        return(f"Полка удалена. Текущий перечень полок: {', '.join(dir_list)}")
    
    return(f"Такой полки не существует. Текущий перечень полок: {', '.join(dir_list)}")
    
# delete_directory_by_number(directories)

# %%
def add_new_doc(doc_list, dir_list):
    new_doc = {}
    new_doc['number'] = input('Введите номер документа: ')
    for document in doc_list:
        if document['number'] == new_doc['number']:
            print('Документ с таким номером уже существует.\nТекущий перечень документов:')
            get_doc_list(doc_list, dir_list)
            return
    new_doc['type'] = input('Введите тип документа: ')
    new_doc['name'] = input('Введите владельца документа: ')
    
    new_doc_dir = input(f'Введите полку для хранения:\nТекущий перечень полок: {", ".join(dir_list)} ')
    if new_doc_dir not in dir_list:
        print('Такой полки не существует. Добавьте полку командой as.')
        print('Текущий перечень документов:')
        get_doc_list(doc_list, dir_list)
        return
    else:
        doc_list.append(new_doc)
        dir_list[new_doc_dir].append(new_doc['number'])
        print('Текущий перечень документов:')
        get_doc_list(doc_list, dir_list)
        return
    
# add_new_doc(documents, directories)

# get_doc_list(documents, directories)

# %%
def delete_doc_by_number(doc_list, dir_list, number):
    for i in range(len(doc_list)):
        if doc_list[i]['number'] == number:
            doc_list.pop(i)
#             pass
            for directory in dir_list.values():
                if number in directory:
                    directory.remove(number)
                    print('Документ удален.')
                    print('Текущий перечень документов:')
                    get_doc_list(doc_list, dir_list)
                    return        
    print('Документ не найден в базе.')
    print('Текущий перечень документов:')
    get_doc_list(doc_list, dir_list)
    return        

# delete_doc_by_number(documents, directories, '10006')

# %%
def move_doc_to_dir(doc_list, dir_list):
    doc_number = input('Введите номер документа: ')
    if get_doc_directory_by_number(dir_list, doc_number) == 'Документ не найден в базе':
        print('Документ не найден в базе')
        return
    
    doc_dir = get_doc_directory_by_number(directories, doc_number).split()[-1]
       
#     print(doc_dir)
    to_dir = input('Введите номер полки: ')
    if to_dir not in dir_list:
        print(f"Такой полки не существует. Текущий перечень полок: {', '.join(dir_list)}")
        return
    
    dir_list[to_dir].append(doc_number)
    dir_list[doc_dir].remove(doc_number)
    
    print('Документ пермещен.')
    print('Текущий перечень документов:')
    get_doc_list(doc_list, dir_list)
    return        
move_doc_to_dir(documents, directories)
# Out:
# Введите номер документа: 10006
# Введите номер полки: 3
# Документ пермещен.
# Текущий перечень документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 3

# %%
def main():
    while True:
        user_input = input('Введите команду:\n')
        if user_input == 'p':
            print(get_doc_owner_by_number(documents, input('Введите номер документа:\n')))
        elif user_input == 's':   
            print(get_doc_directory_by_number(directories, input('Введите номер документа:\n')))
        elif user_input == 'l':   
            get_doc_list(documents, directories)
        elif user_input == 'ads':
            print(add_new_directory(directories, input('Введите номер полки:\n')))
        elif user_input == 'ds':
            print(delete_directory_by_number(directories, input('Введите номер полки:\n')))
        elif user_input == 'ad':
            add_new_doc(documents, directories)
        elif user_input == 'd':
            delete_doc_by_number(documents, directories, input('Введите номер документа:\n'))
        elif user_input == 'm':
            move_doc_to_dir(documents, directories)
        elif user_input == 'q':
            break
main()
# Out:
# Введите команду:
# m
# Введите номер документа: 10006
# Введите номер полки: 2
# Документ пермещен.
# Текущий перечень документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2
# Введите команду:
# m
# Введите номер документа: 54
# Документ не найден в базе
# Введите команду:
# m
# Введите номер документа: 10006
# Введите номер полки: 54
# Такой полки не существует. Текущий перечень полок: 1, 2, 3
# Введите команду:
# q

# %% [markdown]
# Задание 2 (необязательное)
# Вам необходимо дополнить программу из задания 1 более продвинутыми командами.
#
# Пункт 1. Пользователь по команде "ad" может добавить новый документ в данные
# Примеры работы:
#
# 1.
#
# Введите команду:
# ad
#
# Введите номер документа:
# 42
# Введите тип документа:
# multipassport
# Введите владельца документа:
# R2D2
# Введите полку для хранения:
# 3
# Результат:
#
# Документ добавлен. Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2
# №: 42, тип: multipassport, владелец: R2D2, полка хранения: 3
# 2.
#
# Введите команду:
# ad
#
# Введите номер документа:
# 42
# Введите тип документа:
# multipassport
# Введите владельца документа:
# R2D2
# Введите полку для хранения:
# 4
# Результат:
#
# Такой полки не существует. Добавьте полку командой as.
# Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2
# Пункт 2. Пользователь по команде "d" может удалить документ из данных
# Примеры работы:
#
# 1.
#
# Введите команду:
# d
#
# Введите номер документа:
# 10006
# Результат:
#
# Документ удален.
# Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# 2.
#
# Введите команду:
# d
#
# Введите номер документа:
# 123456
# Результат:
#
# Документ не найден в базе.
# Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2
# Пункт 3. Пользователь по команде "m" может переместить документ с полки на полку
# Примеры работы:
#
# 1.
#
# Введите команду:
# m
#
# Введите номер документа:
# 11-2
# Введите номер полки:
# 3
# Результат:
#
# Документ перемещен.
# Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2
# 2.
#
# Введите команду:
# m
#
# Введите номер документа:
# 11-2
# Введите номер полки:
# 10
# Результат:
# Такой полки не существует. Текущий перечень полок: 1, 2, 3.
#
# 3.
#
# Введите команду:
# m
#
# Введите номер документа:
# 42
# Введите номер полки:
# 2
# Результат:
#
# Документ не найден в базе.
# Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2
